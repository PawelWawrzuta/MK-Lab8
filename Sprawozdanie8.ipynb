# %%
#Matematyka Konkretna

# %%
#Laboratorium 8

# %%
#Paweł Wawrzuta https://github.com/PawelWawrzuta/MK-Lab8

# %%
#Wariant 9

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense

def generate_data_sum(num_samples, seq_length):
    X = np.random.choice([0, 0.2, 0.4, 0.6, 0.8, 1], size=(num_samples, seq_length))
    y = np.sum(X, axis=1)
    return X, y

num_samples = 30
seq_length = 20
input_dim = 1
output_dim = 1

X_train, y_train = generate_data_sum(num_samples, seq_length)

model = Sequential()
model.add(SimpleRNN(units=10, input_shape=(seq_length, input_dim)))
model.add(Dense(units=output_dim, activation='linear'))

model.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])

model.fit(X_train, y_train, epochs=100, batch_size=1, verbose=2)

X_test, y_test = generate_data_sum(5, seq_length)
predictions = model.predict(X_test)

for i in range(len(X_test)):
    print("Input:", X_test[i].flatten())
    print("True Output:", y_test[i])
    print("Predicted Output:", predictions[i][0])
    print("\n")

# %% [raw]
# 30/30 - 1s - loss: 73.3159 - accuracy: 0.0000e+00 - 1s/epoch - 37ms/step
# Epoch 2/100
# 30/30 - 0s - loss: 62.0235 - accuracy: 0.0000e+00 - 70ms/epoch - 2ms/step
# Epoch 3/100
# 30/30 - 0s - loss: 52.3777 - accuracy: 0.0000e+00 - 64ms/epoch - 2ms/step
# Epoch 4/100
# 30/30 - 0s - loss: 44.1220 - accuracy: 0.0000e+00 - 63ms/epoch - 2ms/step
# Epoch 5/100
# 30/30 - 0s - loss: 37.3044 - accuracy: 0.0000e+00 - 59ms/epoch - 2ms/step
# Epoch 6/100
# 30/30 - 0s - loss: 31.7601 - accuracy: 0.0000e+00 - 63ms/epoch - 2ms/step
# Epoch 7/100
# 30/30 - 0s - loss: 27.0255 - accuracy: 0.0000e+00 - 68ms/epoch - 2ms/step
# Epoch 8/100
# 30/30 - 0s - loss: 23.1721 - accuracy: 0.0000e+00 - 62ms/epoch - 2ms/step
# Epoch 9/100
# 30/30 - 0s - loss: 19.9171 - accuracy: 0.0000e+00 - 61ms/epoch - 2ms/step
# Epoch 10/100
# 30/30 - 0s - loss: 17.2586 - accuracy: 0.0000e+00 - 62ms/epoch - 2ms/step
# Epoch 11/100
# 30/30 - 0s - loss: 15.0442 - accuracy: 0.0000e+00 - 61ms/epoch - 2ms/step
# Epoch 12/100
# 30/30 - 0s - loss: 13.1035 - accuracy: 0.0000e+00 - 69ms/epoch - 2ms/step
# Epoch 13/100
# 30/30 - 0s - loss: 11.5177 - accuracy: 0.0000e+00 - 87ms/epoch - 3ms/step
# Epoch 14/100
# 30/30 - 0s - loss: 10.1161 - accuracy: 0.0000e+00 - 80ms/epoch - 3ms/step
# Epoch 15/100
# 30/30 - 0s - loss: 8.9233 - accuracy: 0.0000e+00 - 69ms/epoch - 2ms/step
# Epoch 16/100
# 30/30 - 0s - loss: 7.8837 - accuracy: 0.0000e+00 - 78ms/epoch - 3ms/step
# Epoch 17/100
# 30/30 - 0s - loss: 6.9950 - accuracy: 0.0000e+00 - 79ms/epoch - 3ms/step
# Epoch 18/100
# 30/30 - 0s - loss: 6.2447 - accuracy: 0.0000e+00 - 76ms/epoch - 3ms/step
# Epoch 19/100
# 30/30 - 0s - loss: 5.6055 - accuracy: 0.0000e+00 - 77ms/epoch - 3ms/step
# Epoch 20/100
# 30/30 - 0s - loss: 5.0341 - accuracy: 0.0000e+00 - 77ms/epoch - 3ms/step
# Epoch 21/100
# 30/30 - 0s - loss: 4.5888 - accuracy: 0.0000e+00 - 76ms/epoch - 3ms/step
# Epoch 22/100
# 30/30 - 0s - loss: 4.1670 - accuracy: 0.0000e+00 - 67ms/epoch - 2ms/step
# Epoch 23/100
# 30/30 - 0s - loss: 3.8468 - accuracy: 0.0000e+00 - 66ms/epoch - 2ms/step
# Epoch 24/100
# 30/30 - 0s - loss: 3.5633 - accuracy: 0.0000e+00 - 76ms/epoch - 3ms/step
# Epoch 25/100
# 30/30 - 0s - loss: 3.3216 - accuracy: 0.0000e+00 - 78ms/epoch - 3ms/step
# Epoch 26/100
# 30/30 - 0s - loss: 3.1381 - accuracy: 0.0000e+00 - 73ms/epoch - 2ms/step
# Epoch 27/100
# 30/30 - 0s - loss: 2.9687 - accuracy: 0.0000e+00 - 76ms/epoch - 3ms/step
# Epoch 28/100
# 30/30 - 0s - loss: 2.8440 - accuracy: 0.0000e+00 - 77ms/epoch - 3ms/step
# Epoch 29/100
# 30/30 - 0s - loss: 2.7256 - accuracy: 0.0000e+00 - 84ms/epoch - 3ms/step
# Epoch 30/100
# 30/30 - 0s - loss: 2.6598 - accuracy: 0.0000e+00 - 86ms/epoch - 3ms/step
# Epoch 31/100
# 30/30 - 0s - loss: 2.5611 - accuracy: 0.0000e+00 - 92ms/epoch - 3ms/step
# Epoch 32/100
# 30/30 - 0s - loss: 2.5070 - accuracy: 0.0000e+00 - 83ms/epoch - 3ms/step
# Epoch 33/100
# 30/30 - 0s - loss: 2.4596 - accuracy: 0.0000e+00 - 88ms/epoch - 3ms/step
# Epoch 34/100
# 30/30 - 0s - loss: 2.4331 - accuracy: 0.0000e+00 - 83ms/epoch - 3ms/step
# Epoch 35/100
# 30/30 - 0s - loss: 2.3929 - accuracy: 0.0000e+00 - 80ms/epoch - 3ms/step
# Epoch 36/100
# 30/30 - 0s - loss: 2.3732 - accuracy: 0.0000e+00 - 73ms/epoch - 2ms/step
# Epoch 37/100
# 30/30 - 0s - loss: 2.3493 - accuracy: 0.0000e+00 - 82ms/epoch - 3ms/step
# Epoch 38/100
# 30/30 - 0s - loss: 2.3377 - accuracy: 0.0000e+00 - 81ms/epoch - 3ms/step
# Epoch 39/100
# 30/30 - 0s - loss: 2.3201 - accuracy: 0.0000e+00 - 72ms/epoch - 2ms/step
# Epoch 40/100
# 30/30 - 0s - loss: 2.3098 - accuracy: 0.0000e+00 - 75ms/epoch - 2ms/step
# Epoch 41/100
# 30/30 - 0s - loss: 2.3040 - accuracy: 0.0000e+00 - 77ms/epoch - 3ms/step
# Epoch 42/100
# 30/30 - 0s - loss: 2.2984 - accuracy: 0.0000e+00 - 80ms/epoch - 3ms/step
# Epoch 43/100
# 30/30 - 0s - loss: 2.2915 - accuracy: 0.0000e+00 - 72ms/epoch - 2ms/step
# Epoch 44/100
# 30/30 - 0s - loss: 2.2884 - accuracy: 0.0000e+00 - 80ms/epoch - 3ms/step
# Epoch 45/100
# 30/30 - 0s - loss: 2.2845 - accuracy: 0.0000e+00 - 84ms/epoch - 3ms/step
# Epoch 46/100
# 30/30 - 0s - loss: 2.2884 - accuracy: 0.0000e+00 - 85ms/epoch - 3ms/step
# Epoch 47/100
# 30/30 - 0s - loss: 2.2834 - accuracy: 0.0000e+00 - 82ms/epoch - 3ms/step
# Epoch 48/100
# 30/30 - 0s - loss: 2.2799 - accuracy: 0.0000e+00 - 80ms/epoch - 3ms/step
# Epoch 49/100
# 30/30 - 0s - loss: 2.2793 - accuracy: 0.0000e+00 - 78ms/epoch - 3ms/step
# Epoch 50/100
# 30/30 - 0s - loss: 2.2783 - accuracy: 0.0000e+00 - 79ms/epoch - 3ms/step
# Epoch 51/100
# 30/30 - 0s - loss: 2.2769 - accuracy: 0.0000e+00 - 87ms/epoch - 3ms/step
# Epoch 52/100
# 30/30 - 0s - loss: 2.2819 - accuracy: 0.0000e+00 - 86ms/epoch - 3ms/step
# Epoch 53/100
# 30/30 - 0s - loss: 2.2761 - accuracy: 0.0000e+00 - 81ms/epoch - 3ms/step
# Epoch 54/100
# 30/30 - 0s - loss: 2.2752 - accuracy: 0.0000e+00 - 87ms/epoch - 3ms/step
# Epoch 55/100
# 30/30 - 0s - loss: 2.2816 - accuracy: 0.0000e+00 - 77ms/epoch - 3ms/step
# Epoch 56/100
# 30/30 - 0s - loss: 2.2727 - accuracy: 0.0000e+00 - 85ms/epoch - 3ms/step
# Epoch 57/100
# 30/30 - 0s - loss: 2.2777 - accuracy: 0.0000e+00 - 84ms/epoch - 3ms/step
# Epoch 58/100
# 30/30 - 0s - loss: 2.2814 - accuracy: 0.0000e+00 - 92ms/epoch - 3ms/step
# Epoch 59/100
# 30/30 - 0s - loss: 2.2739 - accuracy: 0.0000e+00 - 82ms/epoch - 3ms/step
# Epoch 60/100
# 30/30 - 0s - loss: 2.2721 - accuracy: 0.0000e+00 - 76ms/epoch - 3ms/step
# Epoch 61/100
# 30/30 - 0s - loss: 2.2768 - accuracy: 0.0000e+00 - 75ms/epoch - 3ms/step
# Epoch 62/100
# 30/30 - 0s - loss: 2.2725 - accuracy: 0.0000e+00 - 89ms/epoch - 3ms/step
# Epoch 63/100
# 30/30 - 0s - loss: 2.2786 - accuracy: 0.0000e+00 - 74ms/epoch - 2ms/step
# Epoch 64/100
# 30/30 - 0s - loss: 2.2685 - accuracy: 0.0000e+00 - 78ms/epoch - 3ms/step
# Epoch 65/100
# 30/30 - 0s - loss: 2.2721 - accuracy: 0.0000e+00 - 81ms/epoch - 3ms/step
# Epoch 66/100
# 30/30 - 0s - loss: 2.2775 - accuracy: 0.0000e+00 - 79ms/epoch - 3ms/step
# Epoch 67/100
# 30/30 - 0s - loss: 2.2846 - accuracy: 0.0000e+00 - 73ms/epoch - 2ms/step
# Epoch 68/100
# 30/30 - 0s - loss: 2.2707 - accuracy: 0.0000e+00 - 77ms/epoch - 3ms/step
# Epoch 69/100
# 30/30 - 0s - loss: 2.2702 - accuracy: 0.0000e+00 - 79ms/epoch - 3ms/step
# Epoch 70/100
# 30/30 - 0s - loss: 2.2700 - accuracy: 0.0000e+00 - 81ms/epoch - 3ms/step
# Epoch 71/100
# 30/30 - 0s - loss: 2.2697 - accuracy: 0.0000e+00 - 78ms/epoch - 3ms/step
# Epoch 72/100
# 30/30 - 0s - loss: 2.2857 - accuracy: 0.0000e+00 - 78ms/epoch - 3ms/step
# Epoch 73/100
# 30/30 - 0s - loss: 2.2844 - accuracy: 0.0000e+00 - 75ms/epoch - 2ms/step
# Epoch 74/100
# 30/30 - 0s - loss: 2.2905 - accuracy: 0.0000e+00 - 77ms/epoch - 3ms/step
# Epoch 75/100
# 30/30 - 0s - loss: 2.2634 - accuracy: 0.0000e+00 - 86ms/epoch - 3ms/step
# Epoch 76/100
# 30/30 - 0s - loss: 2.2670 - accuracy: 0.0000e+00 - 72ms/epoch - 2ms/step
# Epoch 77/100
# 30/30 - 0s - loss: 2.2638 - accuracy: 0.0000e+00 - 84ms/epoch - 3ms/step
# Epoch 78/100
# 30/30 - 0s - loss: 2.2696 - accuracy: 0.0000e+00 - 76ms/epoch - 3ms/step
# Epoch 79/100
# 30/30 - 0s - loss: 2.2673 - accuracy: 0.0000e+00 - 73ms/epoch - 2ms/step
# Epoch 80/100
# 30/30 - 0s - loss: 2.2572 - accuracy: 0.0000e+00 - 80ms/epoch - 3ms/step
# Epoch 81/100
# 30/30 - 0s - loss: 2.2579 - accuracy: 0.0000e+00 - 80ms/epoch - 3ms/step
# Epoch 82/100
# 30/30 - 0s - loss: 2.2737 - accuracy: 0.0000e+00 - 80ms/epoch - 3ms/step
# Epoch 83/100
# 30/30 - 0s - loss: 2.2550 - accuracy: 0.0000e+00 - 79ms/epoch - 3ms/step
# Epoch 84/100
# 30/30 - 0s - loss: 2.2590 - accuracy: 0.0000e+00 - 76ms/epoch - 3ms/step
# Epoch 85/100
# 30/30 - 0s - loss: 2.2515 - accuracy: 0.0000e+00 - 76ms/epoch - 3ms/step
# Epoch 86/100
# 30/30 - 0s - loss: 2.2583 - accuracy: 0.0000e+00 - 71ms/epoch - 2ms/step
# Epoch 87/100
# 30/30 - 0s - loss: 2.2460 - accuracy: 0.0000e+00 - 72ms/epoch - 2ms/step
# Epoch 88/100
# 30/30 - 0s - loss: 2.2446 - accuracy: 0.0000e+00 - 80ms/epoch - 3ms/step
# Epoch 89/100
# 30/30 - 0s - loss: 2.2517 - accuracy: 0.0000e+00 - 75ms/epoch - 3ms/step
# Epoch 90/100
# 30/30 - 0s - loss: 2.2465 - accuracy: 0.0000e+00 - 76ms/epoch - 3ms/step
# Epoch 91/100
# 30/30 - 0s - loss: 2.2366 - accuracy: 0.0000e+00 - 73ms/epoch - 2ms/step
# Epoch 92/100
# 30/30 - 0s - loss: 2.2447 - accuracy: 0.0000e+00 - 76ms/epoch - 3ms/step
# Epoch 93/100
# 30/30 - 0s - loss: 2.2262 - accuracy: 0.0000e+00 - 85ms/epoch - 3ms/step
# Epoch 94/100
# 30/30 - 0s - loss: 2.2231 - accuracy: 0.0000e+00 - 78ms/epoch - 3ms/step
# Epoch 95/100
# 30/30 - 0s - loss: 2.2287 - accuracy: 0.0000e+00 - 84ms/epoch - 3ms/step
# Epoch 96/100
# 30/30 - 0s - loss: 2.2318 - accuracy: 0.0000e+00 - 74ms/epoch - 2ms/step
# Epoch 97/100
# 30/30 - 0s - loss: 2.2103 - accuracy: 0.0000e+00 - 82ms/epoch - 3ms/step
# Epoch 98/100
# 30/30 - 0s - loss: 2.1917 - accuracy: 0.0000e+00 - 73ms/epoch - 2ms/step
# Epoch 99/100
# 30/30 - 0s - loss: 2.1948 - accuracy: 0.0000e+00 - 84ms/epoch - 3ms/step
# Epoch 100/100
# 30/30 - 0s - loss: 2.1852 - accuracy: 0.0000e+00 - 84ms/epoch - 3ms/step
#
# 1/1 [==============================] - ETA: 0s
# 1/1 [==============================] - 0s 240ms/step
# Input: [0.4 1.  1.  1.  0.  0.4 0.4 0.  0.  0.6 0.  0.2 0.2 0.8 0.2 0.2 0.  0.8
#  0.8 1. ]
# True Output: 9.0
# Predicted Output: 9.354192
#
#
# Input: [0.  1.  0.  0.  0.2 0.8 0.  0.  0.  0.4 1.  0.2 0.2 0.4 0.4 0.2 0.8 0.8
#  0.6 0.6]
# True Output: 7.599999999999999
# Predicted Output: 9.280601
#
#
# Input: [0.4 1.  1.  1.  0.  1.  0.8 0.2 1.  0.8 0.6 0.4 0.8 0.8 0.2 0.2 0.8 0.6
#  0.8 0.6]
# True Output: 13.0
# Predicted Output: 9.284169
#
#
# Input: [0.2 0.8 1.  0.2 0.2 0.4 0.4 0.2 0.8 0.6 0.  0.8 1.  0.2 0.8 0.8 0.8 1.
#  1.  0.2]
# True Output: 11.4
# Predicted Output: 9.176209
#
#
# Input: [0.8 1.  0.  0.2 0.6 0.2 0.4 1.  0.  0.  0.2 0.6 0.  0.6 0.  0.6 0.8 0.6
#  0.  0.6]
# True Output: 8.2
# Predicted Output: 9.260292
